# %% [markdown]
# # Head Injury Criterion Prediction

# %%
# Import modules

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'data', 'data_description.pdf', 'hic-prediction.ipynb']

# %%
# set paths
project_path = os.getcwd()
data_path = project_path + '/data'

# %%
def std_col_names(df):
    df.columns = df.columns.str.lower().str.strip().str.replace(' ', '_')
    return df

# %%
# load data to frame
veh = pd.read_csv(data_path+'/veh.psv', delimiter= '\t')
veh = std_col_names(veh)

# %%
veh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12131 entries, 0 to 12130
# Data columns (total 93 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tstno    12131 non-null  int64
#  1   vehno    12131 non-null  int64
#  2   make     12131 non-null  int64
#  3   maked    12131 non-null  object
#  4   model    12131 non-null  int64
#  5   modeld   12131 non-null  object
#  6   year     11953 non-null  float64
#  7   nhtsano  6470 non-null   object
#  8   body     8517 non-null   object
#  9   bodyd    11807 non-null  object
#  10  vin      7824 non-null   object
#  11  engine   11660 non-null  object
#  12  engined  11660 non-null  object
#  13  engdsp   10709 non-null  float64
#  14  transm   8195 non-null   object
#  15  transmd  11699 non-null  object
#  16  vehtwt   11797 non-null  float64
#  17  curbwt   637 non-null    float64
#  18  whlbas   11355 non-null  float64
#  19  vehlen   11488 non-null  float64
#  20  vehwid   11280 non-null  float64
#  21  vehcg    11081 non-null  float64
#  22  strsep   6584 non-null   object
#  23  strsepd  11626 non-null  object
#  24  colmec   9597 non-null   object
#  25  colmecd  11626 non-null  object
#  26  modind   11612 non-null  object
#  27  modindd  11611 non-null  object
#  28  moddsc   7794 non-null   object
#  29  bx1      9570 non-null   float64
#  30  bx2      9263 non-null   float64
#  31  bx3      9263 non-null   float64
#  32  bx4      9319 non-null   float64
#  33  bx5      9328 non-null   float64
#  34  bx6      9316 non-null   float64
#  35  bx7      9329 non-null   float64
#  36  bx8      9327 non-null   float64
#  37  bx9      9339 non-null   float64
#  38  bx10     9317 non-null   float64
#  39  bx11     9329 non-null   float64
#  40  bx12     9308 non-null   float64
#  41  bx13     9311 non-null   float64
#  42  bx14     9272 non-null   float64
#  43  bx15     9267 non-null   float64
#  44  bx16     9317 non-null   float64
#  45  bx17     9315 non-null   float64
#  46  bx18     9328 non-null   float64
#  47  bx19     9528 non-null   float64
#  48  bx20     9540 non-null   float64
#  49  bx21     9294 non-null   float64
#  50  vehspd   12013 non-null  float64
#  51  crbang   11797 non-null  float64
#  52  pdof     11559 non-null  float64
#  53  bmpeng   3066 non-null   object
#  54  bmpengd  11579 non-null  object
#  55  sileng   3125 non-null   object
#  56  silengd  11611 non-null  object
#  57  apleng   2547 non-null   object
#  58  aplengd  11611 non-null  object
#  59  dpd1     10555 non-null  float64
#  60  dpd2     10535 non-null  float64
#  61  dpd3     10539 non-null  float64
#  62  dpd4     10537 non-null  float64
#  63  dpd5     10523 non-null  float64
#  64  dpd6     10545 non-null  float64
#  65  vdi      7450 non-null   object
#  66  lencnt   10650 non-null  float64
#  67  damdst   10498 non-null  float64
#  68  crhdst   10541 non-null  float64
#  69  ax1      9535 non-null   float64
#  70  ax2      9234 non-null   float64
#  71  ax3      3977 non-null   float64
#  72  ax4      9309 non-null   float64
#  73  ax5      9317 non-null   float64
#  74  ax6      9309 non-null   float64
#  75  ax7      9317 non-null   float64
#  76  ax8      9319 non-null   float64
#  77  ax9      9327 non-null   float64
#  78  ax10     9325 non-null   float64
#  79  ax11     9316 non-null   float64
#  80  ax12     9303 non-null   float64
#  81  ax13     9276 non-null   float64
#  82  ax14     9243 non-null   float64
#  83  ax15     9244 non-null   float64
#  84  ax16     9300 non-null   float64
#  85  ax17     9296 non-null   float64
#  86  ax18     9310 non-null   float64
#  87  ax19     9495 non-null   float64
#  88  ax20     9508 non-null   float64
#  89  ax21     9286 non-null   float64
#  90  carang   10228 non-null  float64
#  91  vehor    10213 non-null  float64
#  92  vehcom   9282 non-null   object
# dtypes: float64(64), int64(4), object(25)
# memory usage: 8.6+ MB

# %%
num_cols_veh = veh.select_dtypes(include=['int64', 'float64']).columns.to_list()
cat_cols_veh = veh.select_dtypes(include=['object']).columns.to_list()

len(num_cols_veh), len(cat_cols_veh)
# Out:
# (68, 25)

# %%
(veh.describe()).T
# Out:
#           count         mean           std   min     25%     50%     75%  \
# tstno   12131.0  5210.088946   3307.114848   1.0  2226.5  5048.0  8058.0
# vehno   12131.0     1.227022      0.418924   1.0     1.0     1.0     1.0
# make    12131.0    27.044926     25.930954   1.0     7.0    23.0    32.0
# model   12131.0    20.729618     25.942436   1.0     2.0    11.0    27.0
# year    11953.0  1450.450431    894.136012   0.0     0.0  1997.0  2008.0
# ...         ...          ...           ...   ...     ...     ...     ...
# ax19     9495.0  6962.071617  23562.217251   0.0     0.0  3216.0  4270.0
# ax20     9508.0  6922.611695  23551.150903   0.0     0.0  3128.5  4212.0
# ax21     9286.0  6135.489446  27386.443756 -10.0     0.0     0.0   450.0
# carang  10228.0    68.312867    242.260414   0.0     0.0     0.0     0.0
# vehor   10213.0    79.714579    262.354039   0.0     0.0     0.0     0.0
#
#              max
# tstno    11847.0
# vehno        2.0
# make       102.0
# model       99.0
# year      2021.0
# ...          ...
# ax19    999999.0
# ax20    999999.0
# ax21    999999.0
# carang     999.0
# vehor      999.0
#
# [68 rows x 8 columns]

# %%
veh.describe(include='object').T
# Out:
#          count unique                  top  freq
# maked    12131     93                NHTSA  2747
# modeld   12131    804  DEFORMABLE IMPACTOR  1850
# nhtsano   6470   4819                  999    85
# body      8517     20                   4S  3547
# bodyd    11807     23      FOUR DOOR SEDAN  3547
# vin       7824   6366    1FTEW1C85GFA99353    76
# engine   11660     19                 NAPP  3463
# engined  11660     20       NOT APPLICABLE  3461
# transm    8195     12                   AF  3421
# transmd  11699     15       NOT APPLICABLE  3503
# strsep    6584      5                   UN  6046
# strsepd  11626      7              UNKNOWN  6040
# colmec    9597     11                  UNK  4965
# colmecd  11626     10       NOT APPLICABLE  5065
# modind   11612      7                    P  7531
# modindd  11611      6   PRODUCTION VEHICLE  7531
# moddsc    7794    731          NO COMMENTS  2157
# bmpeng    3066      7                   DE  2819
# bmpengd  11579      8       NOT APPLICABLE  8513
# sileng    3125      5                   DE  2463
# silengd  11611      6       NOT APPLICABLE  8486
# apleng    2547      5                   DE  1783
# aplengd  11611      6       NOT APPLICABLE  9064
# vdi       7450    348              9999999  1785
# vehcom    9282   3020          NO COMMENTS  3089

# %%
null_veh = pd.DataFrame(veh.isna().sum()).reset_index()\
                .rename(columns= {'index':'feature', 0:'null_count'}).sort_values(by='null_count', ascending = False)
null_veh
# Out:
#    feature  null_count
# 17  curbwt       11494
# 57  apleng        9584
# 53  bmpeng        9065
# 55  sileng        9006
# 71     ax3        8154
# ..     ...         ...
# 4    model           0
# 3    maked           0
# 2     make           0
# 1    vehno           0
# 0    tstno           0
#
# [93 rows x 2 columns]

# %%
null_veh.loc[null_veh['feature']=='bx1', ['null_count']]
# Out:
#     null_count
# 29        2561

# %%
def exclude_feature(df, null_count):
    """
    Fetch list of numerical columns from dataframe
    where number of null values exceed threshold `null_count`
    """
    return [df.iloc[idx][0] for idx in range(len(df)) if df.iloc[idx][1] > null_count]

excl_veh = exclude_feature(null_veh, 2835)

# %%
veh.columns
# Out:
# Index(['tstno', 'vehno', 'make', 'maked', 'model', 'modeld', 'year', 'nhtsano',
#        'body', 'bodyd', 'vin', 'engine', 'engined', 'engdsp', 'transm',
#        'transmd', 'vehtwt', 'curbwt', 'whlbas', 'vehlen', 'vehwid', 'vehcg',
#        'strsep', 'strsepd', 'colmec', 'colmecd', 'modind', 'modindd', 'moddsc',
#        'bx1', 'bx2', 'bx3', 'bx4', 'bx5', 'bx6', 'bx7', 'bx8', 'bx9', 'bx10',
#        'bx11', 'bx12', 'bx13', 'bx14', 'bx15', 'bx16', 'bx17', 'bx18', 'bx19',
#        'bx20', 'bx21', 'vehspd', 'crbang', 'pdof', 'bmpeng', 'bmpengd',
#        'sileng', 'silengd', 'apleng', 'aplengd', 'dpd1', 'dpd2', 'dpd3',
#        'dpd4', 'dpd5', 'dpd6', 'vdi', 'lencnt', 'damdst', 'crhdst', 'ax1',
#        'ax2', 'ax3', 'ax4', 'ax5', 'ax6', 'ax7', 'ax8', 'ax9', 'ax10', 'ax11',
#        'ax12', 'ax13', 'ax14', 'ax15', 'ax16', 'ax17', 'ax18', 'ax19', 'ax20',
#        'ax21', 'carang', 'vehor', 'vehcom'],
#       dtype='object')

# %%
feature_cols_veh = ['tstno', 'vehno', 'body', 'engine', 'engdsp', 'transm', 
               'whlbas','vehlen', 'vehwid', 'vehcg', 'modind', 'vehspd',
                'crbang', 'pdof', 'lencnt']

# %%
feature = 'vehor'
(veh[feature]).isna().value_counts(normalize= True, sort= True), ((veh[feature])==0).value_counts(normalize=True, sort= False)
# Out:
# (False    0.841893
#  True     0.158107
#  Name: vehor, dtype: float64,
#  True     0.719809
#  False    0.280191
#  Name: vehor, dtype: float64)

# %%
veh[feature].value_counts()
# veh[feature].sample(20)
# Out:
# 0.0      8732
# 999.0     765
# 90.0      475
# 15.0      123
# 9.0        43
# 99.0       37
# 7.0        18
# 75.0       11
# 23.0        4
# 26.0        2
# 45.0        2
# 60.0        1
# Name: vehor, dtype: int64

# %%
def dirty_val_ratio(df, feature, vals)
    return len(df[~df[feature].isin([np.nan, 0, 999])])/len(veh)
# Out:
# 0.05902233946088534

# %%
# load data to frame
occ = pd.read_csv(data_path+'/occ.psv', delimiter= '|')
occ = std_col_names(occ)
occ = occ.rename(columns= {'ctrh2d':'cntrh2d', 'ctrl2':'cntrl2'})

# %%
occ.head()
# Out:
#    tstno  vehno occloc           occlocd occtyp                  occtypd  \
# 0      1      1     01   LEFT FRONT SEAT     P5           PART 572 DUMMY
# 1      1      1     02  RIGHT FRONT SEAT     P5           PART 572 DUMMY
# 2      2      1     01   LEFT FRONT SEAT     P5           PART 572 DUMMY
# 3      2      1     02  RIGHT FRONT SEAT     P5           PART 572 DUMMY
# 4      2      2     01   LEFT FRONT SEAT     SD  NHTSA SIDE IMPACT DUMMY
#
#    occage occsex occsexd  occht  ...      t2 clip3m lfem rfem   csi lbelt  \
# 0     NaN      M    MALE    NaN  ...   96.45   60.6  0.0  0.0  60.0   0.0
# 1     NaN      M    MALE    NaN  ...  109.28   45.4  0.0  0.0  60.0   0.0
# 2     NaN      M    MALE    NaN  ...  165.23    0.0  0.0  0.0  51.0   0.0
# 3     NaN      M    MALE    NaN  ...  164.48    0.0  0.0  0.0  35.0   0.0
# 4     NaN      M    MALE    NaN  ...  127.28   16.2  0.0  0.0  60.0   0.0
#
#     sbelt tti  pelvg       occcom
# 0  7099.0 NaN    NaN  NO COMMENTS
# 1  5694.0 NaN    NaN  NO COMMENTS
# 2     0.0 NaN    NaN  NO COMMENTS
# 3     0.0 NaN    NaN  NO COMMENTS
# 4     0.0 NaN    NaN  NO COMMENTS
#
# [5 rows x 57 columns]

# %%
occ.columns
# Out:
# Index(['tstno', 'vehno', 'occloc', 'occlocd', 'occtyp', 'occtypd', 'occage',
#        'occsex', 'occsexd', 'occht', 'occwt', 'mthcal', 'mthcald', 'dumsiz',
#        'dumsizd', 'dumman', 'dummod', 'dumdsc', 'hh', 'hw', 'hr', 'hs', 'cd',
#        'cs', 'ad', 'hd', 'kd', 'hb', 'nb', 'cb', 'kb', 'seposn', 'seposnd',
#        'cntrh1', 'cntrh1d', 'cntrh2', 'cntrh2d', 'cntrc1', 'cntrc1d', 'cntrc2',
#        'cntrc2d', 'cntrl1', 'cntrl1d', 'ctrl2', 'cntrl2d', 'hic', 't1', 't2',
#        'clip3m', 'lfem', 'rfem', 'csi', 'lbelt', 'sbelt', 'tti', 'pelvg',
#        'occcom'],
#       dtype='object')

# %%
feature_cols_occ = ['tstno', 'vehno','occloc','occsex', 'seposn',
                    'cntrh1', 'cntrh2', 'cntrc1', 'cntrc2', 'cntrl1',
                    'ctrl2', 't1', 't2','hic'     
]

# %%
feature = 'pelvg'
(occ[feature]).isna().value_counts(normalize= True, sort= True), ((occ[feature])==0).value_counts(normalize=True, sort= False)
# Out:
# (False    0.690599
#  True     0.309401
#  Name: pelvg, dtype: float64,
#  False    0.436869
#  True     0.563131
#  Name: pelvg, dtype: float64)

# %%
occ[feature].value_counts()
# Out:
# 0.00        8871
# 9.00         280
# 9999.99      140
# 99999.00      88
# 50.00         17
#             ...
# 73.40          1
# 73.60          1
# 59.90          1
# 85.60          1
# 67.60          1
# Name: pelvg, Length: 744, dtype: int64

# %%
# Feature list from both tables
feature_cols_veh = ['tstno', 'vehno', 'body', 'engine', 'engdsp', 'transm', 
               'whlbas','vehlen', 'vehwid', 'vehcg', 'modind', 'vehspd',
                'crbang', 'pdof', 'lencnt']

feature_cols_occ = ['tstno', 'vehno','occloc','occsex', 'seposn',
                    'cntrh1', 'cntrh2', 'cntrc1', 'cntrc2', 'cntrl1',
                    'cntrl2', 't1', 't2', 'hic'     
]

# %%
# Extracting data based on selected features
veh_df = veh[feature_cols_veh]
occ_df = occ[feature_cols_occ]
len(veh_df), len(occ_df)
# Out:
# (12131, 15753)

# %%
# Merge DFs on composite keys
merged_df = pd.merge(left= veh_df, right= occ_df, how= 'inner',\
                    on= ['tstno', 'vehno']
                    )
# merged_df['hic'] = merged_df['hic'].dropna(inplace= True)

merged_df = merged_df[(merged_df['hic']>150) & (merged_df['hic'] < 1500)]

# %%
# merged_df = merged_df[(merged_df['hic']>150) & (merged_df['hic'] < 1500)]
merged_df#.isna().value_counts(normalize=True)
# Out:
#        tstno  vehno body engine  engdsp transm  whlbas  vehlen  vehwid  \
# 0          1      1   5H   OTHR     2.8     AF  2664.0  4488.0  1730.0
# 1          1      1   5H   OTHR     2.8     AF  2664.0  4488.0  1730.0
# 4          2      2   4S   S6IF     3.7     AR  2858.0  5110.0  1862.0
# 5          2      2   4S   S6IF     3.7     AR  2858.0  5110.0  1862.0
# 7          3      2   3H   4CTF     1.5     MF  2400.0  3945.0  1610.0
# ...      ...    ...  ...    ...     ...    ...     ...     ...     ...
# 15733  11654      1   4S   NAPP     NaN    NaN     NaN     NaN     NaN
# 15737  11820      2   UV   4CTF     2.0     M4  2669.0  4463.0  1776.0
# 15742  11825      1   UV   4CIF     2.0     A4  2992.0  5025.0  1956.0
# 15743  11827      1   OT   OTHR     0.0    NaN     0.0     0.0  1800.0
# 15744  11827      1   OT   OTHR     0.0    NaN     0.0     0.0  1800.0
#
#         vehcg  ... seposn  cntrh1  cntrh2  cntrc1  cntrc2 cntrl1 cntrl2  \
# 0      1069.0  ...     CN      SW      UN      SW      UN     DP     UN
# 1      1069.0  ...     CN      NO      UN      NO      UN     NO     UN
# 4      1240.0  ...     CN      SD      UN      OT      UN     NO     UN
# 5      1240.0  ...     NO      UN      UN      OT      UN     NO     UN
# 7       986.0  ...     CN      SD      UN      OT      UN     OT     UN
# ...       ...  ...    ...     ...     ...     ...     ...    ...    ...
# 15733     NaN  ...     NO      NO      NO      NO      NO     NO     NO
# 15737  1240.0  ...     NO      AB      OT      OT      NO     DR     NO
# 15742  1494.0  ...     FW      AB      OT      NO      NO     DR     NO
# 15743     0.0  ...    NaN      AB      AB      AB      UN     DP     SC
# 15744     0.0  ...    NaN      AB      NO      AB      NO     DP     OT
#
#           t1      t2     hic
# 0      69.68   96.45  1041.0
# 1      68.55  109.28  1118.0
# 4      73.43  127.28   464.0
# 5      91.73   96.08   552.0
# 7      70.95  111.00  1300.0
# ...      ...     ...     ...
# 15733  72.60   57.60   272.0
# 15737  46.55   72.50   303.0
# 15742  43.50   73.30   268.0
# 15743   0.00    0.00   310.0
# 15744  73.00   88.00   463.0
#
# [10362 rows x 27 columns]

# %%
# Exclude the first two columns because they are primary keys
# Exclude last column and store as target
df = merged_df[merged_df.columns.to_list()[2:-1]]
target = merged_df['hic']
df.head()
# Out:
#   body engine  engdsp transm  whlbas  vehlen  vehwid   vehcg modind  vehspd  \
# 0   5H   OTHR     2.8     AF  2664.0  4488.0  1730.0  1069.0      P    64.2
# 1   5H   OTHR     2.8     AF  2664.0  4488.0  1730.0  1069.0      P    64.2
# 4   4S   S6IF     3.7     AR  2858.0  5110.0  1862.0  1240.0      M     0.0
# 5   4S   S6IF     3.7     AR  2858.0  5110.0  1862.0  1240.0      M     0.0
# 7   3H   4CTF     1.5     MF  2400.0  3945.0  1610.0   986.0      M     0.0
#
#    ...  occsex  seposn  cntrh1 cntrh2 cntrc1 cntrc2 cntrl1 cntrl2     t1  \
# 0  ...       M      CN      SW     UN     SW     UN     DP     UN  69.68
# 1  ...       M      CN      NO     UN     NO     UN     NO     UN  68.55
# 4  ...       M      CN      SD     UN     OT     UN     NO     UN  73.43
# 5  ...       M      NO      UN     UN     OT     UN     NO     UN  91.73
# 7  ...       M      CN      SD     UN     OT     UN     OT     UN  70.95
#
#        t2
# 0   96.45
# 1  109.28
# 4  127.28
# 5   96.08
# 7  111.00
#
# [5 rows x 24 columns]

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.to_list()
cat_cols = df.select_dtypes(include=['object']).columns.to_list()

cat_cols
# Out:
# ['body',
#  'engine',
#  'transm',
#  'modind',
#  'occloc',
#  'occsex',
#  'seposn',
#  'cntrh1',
#  'cntrh2',
#  'cntrc1',
#  'cntrc2',
#  'cntrl1',
#  'cntrl2']

# %%
map1={feature: list(zip(veh[feature].unique(), veh[feature+'d'].unique())) for feature in cat_cols[:4]}
map2 = {feature: list(zip(occ[feature].unique(), occ[feature+'d'].unique())) for feature in cat_cols[4:]}
feature_map = {**map1, **map2}

feature_map['cntrl2'], occ['cntrl2'].unique(),occ['cntrl2d'].unique()
# Out:
# ([('UN', 'UNKNOWN'),
#   ('NO', 'NONE'),
#   ('DP', 'DASHPANEL'),
#   ('OT', 'OTHER'),
#   ('SB', 'SEAT BACK'),
#   ('SC', 'STEERING COLUMN'),
#   ('DR', 'DOOR'),
#   (nan, 'DOOR PANEL')],
#  array(['UN', 'NO', 'DP', 'OT', 'SB', 'SC', 'DR', nan], dtype=object),
#  array(['UNKNOWN', 'NONE', 'DASHPANEL', 'OTHER', 'SEAT BACK',
#         'STEERING COLUMN', 'DOOR', 'DOOR PANEL', nan], dtype=object))

# %%
feature_map
# Out:
# {'body': [('5H', 'FIVE DOOR HATCHBACK'),
#   ('4S', 'FOUR DOOR SEDAN'),
#   ('3H', 'THREE DOOR HATCHBACK'),
#   (nan, 'NOT APPLICABLE'),
#   ('VN', 'VAN'),
#   ('2S', 'TWO DOOR SEDAN'),
#   ('2C', 'TWO DOOR COUPE'),
#   ('OT', 'OTHER'),
#   ('PU', 'PICKUP TRUCK'),
#   ('TR', 'TRUCK'),
#   ('SW', 'STATION WAGON'),
#   ('CV', 'CONVERTIBLE'),
#   ('UV', 'UTILITY VEHICLE'),
#   ('MH', 'MOTOR HOME'),
#   ('BU', 'C-10'),
#   ('LM', 'BUS'),
#   ('MV', 'LIMOUSINE'),
#   ('EX', 'SILVERADO'),
#   ('4P', 'MINIVAN'),
#   ('UN', 'EXTENDED CAB PICKUP'),
#   ('3C', nan)],
#  'engine': [('OTHR', 'OTHER'),
#   ('V8IF', 'V8 INLINE FRONT'),
#   ('S6IF', 'STRAIGHT 6 INLINE FRONT'),
#   ('4CTF', '4 CYLINDER TRANSVERSE FRONT'),
#   ('S6TF', 'STRAIGHT 6 TRANSVERSE FRONT'),
#   ('NAPP', 'NOT APPLICABLE'),
#   ('4CIF', '4 CYLINDER INLINE FRONT'),
#   ('V6IF', 'V6 INLINE FRONT'),
#   ('ELEC', 'ELECTRIC MOTOR'),
#   ('ROTR', 'ROTARY'),
#   ('4CLR', '4 CYLINDER REAR'),
#   ('S5IF', 'STRAIGHT 5 INLINE FRONT'),
#   ('4CLM', '4 CYLINDER MID'),
#   ('3CTF', '3 CYLINDER TRANSVERSE FRONT'),
#   ('V6TF', 'V6 TRANSVERSE FRONT'),
#   ('OTH', 'NOT APLLICABLE'),
#   ('UNKN', 'UNKNOWN'),
#   (nan, nan),
#   ('V8TF', 'V8 TRANSVERSE FRONT'),
#   ('5CTF', 'S6TF')],
#  'transm': [('AF', 'AUTOMATIC - FRONT WHEEL DRIVE'),
#   ('AR', 'AUTOMATIC - REAR WHEEL DRIVE'),
#   ('MF', 'MANUAL - FRONT WHEEL DRIVE'),
#   (nan, 'NOT APPLICABLE'),
#   ('MR', 'MANUAL - REAR WHEEL DRIVE'),
#   ('OT', 'OTHER'),
#   ('A4', 'AUTOMATIC - FOUR WHEEL DRIVE'),
#   ('M4', 'MANUAL - FOUR WHEEL DRIVE'),
#   ('UN', 'UNKNOWN'),
#   ('.', 'NOT APLLICABLE'),
#   ('CV', '.'),
#   ('6A', nan),
#   ('5A', 'CONTINUOUS VARIABLE TRANSMISSION')],
#  'modind': [('P', 'PRODUCTION VEHICLE'),
#   ('M', 'MODIFIED VEHICLE'),
#   ('R', 'RESEARCH VEHICLE'),
#   ('U', 'UNKNOWN'),
#   ('N', 'NOT APPLICABLE'),
#   ('O', 'OTHER'),
#   ('.', nan)],
#  'occloc': [('01', 'LEFT FRONT SEAT'),
#   ('02', 'RIGHT FRONT SEAT'),
#   ('04', 'LEFT REAR SEAT'),
#   ('06', 'CENTER REAR SEAT'),
#   ('03', 'RIGHT REAR SEAT'),
#   ('OT', 'OTHER'),
#   ('05', 'CENTER FRONT SEAT'),
#   ('07', 'LEFT THIRD SEAT'),
#   ('L6', 'LEFT ROW 2, CENTER'),
#   ('L8', 'LEFT ROW 3, CENTER'),
#   ('R3', 'RIGHT ROW 2, RIGHT'),
#   ('R4', 'RIGHT ROW 2, AISLE'),
#   ('R7', 'RIGHT ROW 3, RIGHT'),
#   ('R9', 'RIGHT ROW 3, AISLE'),
#   ('L7', 'LEFT ROW 3, AISLE'),
#   ('L9', 'LEFT ROW 3, LEFT'),
#   ('R8', 'RIGHT ROW 3, CENTER'),
#   ('L3', 'LEFT ROW 2, AISLE'),
#   ('L4', 'LEFT ROW 2, LEFT'),
#   ('09', 'RIGHT THIRD SEAT'),
#   ('08', 'CENTER THIRD SEAT'),
#   ('10', 'LEFT FOURTH SEAT'),
#   ('12', 'RIGHT FOURTH SEAT'),
#   ('AA', nan),
#   ('BB', 'LEFT ROW 12, AISLE'),
#   ('BD', 'RIGHT ROW 13, RIGHT'),
#   ('LD', 'RIGHT ROW 13, AISLE'),
#   ('LF', 'LEFT ROW 5, LEFT'),
#   ('LM', 'LEFT ROW 5, AISLE'),
#   ('LO', 'LEFT ROW 8, LEFT'),
#   ('LS', 'LEFT ROW 8, AISLE'),
#   ('LU', 'LEFT ROW 10, LEFT'),
#   ('LY', 'LEFT ROW 10, AISLE'),
#   ('RA', 'LEFT ROW 12, LEFT'),
#   ('RC', 'RIGHT ROW 4, RIGHT'),
#   ('RD', 'RIGHT ROW 4, AISLE'),
#   ('RF', 'RIGHT ROW 5, RIGHT'),
#   ('RG', 'RIGHT ROW 5, AISLE'),
#   ('RI', 'RIGHT ROW 6, RIGHT'),
#   ('RJ', 'RIGHT ROW 6, AISLE'),
#   ('RL', 'RIGHT ROW 7, RIGHT'),
#   ('RP', 'RIGHT ROW 7, AISLE'),
#   ('RR', 'RIGHT ROW 9, RIGHT'),
#   ('RV', 'RIGHT ROW 9, AISLE'),
#   ('RX', 'RIGHT ROW 11, RIGHT'),
#   ('11', 'RIGHT ROW 11, AISLE'),
#   ('RM', 'CENTER FOURTH SEAT'),
#   ('RO', 'RIGHT ROW 8, RIGHT'),
#   ('RS', 'RIGHT ROW 8, AISLE'),
#   ('RU', 'RIGHT ROW 10, RIGHT'),
#   ('RY', 'RIGHT ROW 10, AISLE'),
#   (nan, 'RIGHT ROW 12, RIGHT')],
#  'occsex': [('M', 'MALE'),
#   ('N', 'NOT APPLICABLE'),
#   ('U', 'UNKNOWN'),
#   ('F', 'FEMALE'),
#   (nan, 'A')],
#  'seposn': [('CN', 'CENTER POSITION'),
#   ('NO', 'NONADJUSTABLE SEAT'),
#   ('UN', 'UNKNOWN'),
#   ('RW', 'REARWARD OF CENTER POSITION'),
#   ('FW', 'FORWARD OF CENTER POSITION'),
#   ('OT', 'OTHER'),
#   (nan, 'NOT APLLICABLE'),
#   ('.', 'NOT APPLICABLE')],
#  'cntrh1': [('SW', 'STEERING WHEEL'),
#   ('NO', 'NONE'),
#   ('SD', 'SIDE WINDOW'),
#   ('UN', 'UNKNOWN'),
#   ('OT', 'OTHER'),
#   ('DP', 'DASHPANEL'),
#   ('WS', 'WINDSHIELD'),
#   ('SB', 'SEAT BACK'),
#   ('OC', 'ANOTHER OCCUPANT'),
#   ('HW', 'HEADER - WINDSHIELD'),
#   ('BP', 'B PILLAR'),
#   ('HS', 'HEADER - SIDE'),
#   ('HK', 'KNEE'),
#   ('SR', 'STEERING WHEEL RIM'),
#   ('SH', 'STEERING WHEEL HUB'),
#   ('OV', 'OTHER VEHICLE'),
#   ('CP', 'C PILLAR'),
#   ('AB', 'AIR BAG'),
#   ('AP', 'A PILLAR'),
#   ('HC', 'CHEST'),
#   (nan, nan),
#   ('SS', 'SIDE SILL')],
#  'cntrh2': [('UN', 'UNKNOWN'),
#   ('NO', 'NONE'),
#   ('SR', 'STEERING WHEEL RIM'),
#   ('DP', 'DASHPANEL'),
#   ('SW', 'STEERING WHEEL'),
#   ('WS', 'WINDSHIELD'),
#   ('SH', 'STEERING WHEEL HUB'),
#   ('OT', 'OTHER'),
#   ('HK', 'KNEE'),
#   ('HS', 'HEADER - SIDE'),
#   ('OC', 'ANOTHER OCCUPANT'),
#   ('HW', 'HEADER - WINDSHIELD'),
#   ('SB', 'SEAT BACK'),
#   ('BP', 'B PILLAR'),
#   ('SD', 'SIDE WINDOW'),
#   ('OV', 'OTHER VEHICLE'),
#   ('HC', 'CHEST'),
#   ('CP', 'THER'),
#   ('AB', 'C PILLAR'),
#   ('AP', 'AIR BAG'),
#   (nan, 'A PILLAR'),
#   ('SS', nan)],
#  'cntrc1': [('SW', 'STEERING WHEEL'),
#   ('NO', 'NONE'),
#   ('OT', 'OTHER'),
#   ('UN', 'UNKNOWN'),
#   ('SB', 'SEAT BACK'),
#   ('DP', 'DASHPANEL'),
#   ('AB', 'AIR BAG'),
#   ('DR', 'OTHE5R'),
#   ('SP', 'DOOR PANEL'),
#   (nan, 'SIDE PANEL')],
#  'cntrc2': [('UN', 'UNKNOWN'),
#   ('NO', 'NONE'),
#   ('DP', 'DASHPANEL'),
#   ('SW', 'STEERING WHEEL'),
#   ('SB', 'SEAT BACK'),
#   ('OT', 'OTHER'),
#   ('AB', 'AIR BAG'),
#   (nan, nan)],
#  'cntrl1': [('DP', 'DASHPANEL'),
#   ('NO', 'NONE'),
#   ('OT', 'OTHER'),
#   ('UN', 'UNKNOWN'),
#   ('SB', 'SEAT BACK'),
#   ('KR', 'KNEE RESTRAINT'),
#   ('SC', 'STEERING COLUMN'),
#   ('DR', 'DOOR PANEL'),
#   ('SP', 'SIDE PANEL'),
#   (nan, 'DORR PANEL')],
#  'cntrl2': [('UN', 'UNKNOWN'),
#   ('NO', 'NONE'),
#   ('DP', 'DASHPANEL'),
#   ('OT', 'OTHER'),
#   ('SB', 'SEAT BACK'),
#   ('SC', 'STEERING COLUMN'),
#   ('DR', 'DOOR'),
#   (nan, 'DOOR PANEL')]}

# %%
occ.loc[occ['cntrl2']=='DR',['cntrl2d']]
# Out:
#           cntrl2d
# 4100         DOOR
# 4101   DOOR PANEL
# 5564   DOOR PANEL
# 5720   DOOR PANEL
# 7307         DOOR
# 7308         DOOR
# 7672         DOOR
# 11147        DOOR
# 11394        DOOR
# 11554        DOOR
# 11555        DOOR
# 11556        DOOR
# 11951        DOOR
# 12991        DOOR
# 13148        DOOR
# 13389        DOOR
# 13956        DOOR
# 14220        DOOR
# 14552        DOOR
# 14633        DOOR
# 14684        DOOR
# 14736        DOOR
# 14738        DOOR
# 14751        DOOR
# 14752        DOOR
# 14821        DOOR
# 14823        DOOR
# 14833        DOOR
# 14848        DOOR
# 14849        DOOR
# 14850        DOOR
# 14862        DOOR
# 14863        DOOR
# 14947        DOOR
# 14961        DOOR
# 14973        DOOR
# 14992        DOOR
# 15124        DOOR
# 15208        DOOR
# 15209        DOOR
# 15242        DOOR
# 15243        DOOR
# 15244        DOOR
# 15254        DOOR
# 15259        DOOR
# 15276        DOOR
# 15299        DOOR
# 15313        DOOR
# 15348        DOOR
# 15464        DOOR
# 15547        DOOR
# 15554        DOOR
# 15594        DOOR
# 15639        DOOR
# 15640        DOOR
# 15689        DOOR

# %%
merged_df['time'] = abs(merged_df['t1']-merged_df['t2'])

# %%
corr_matrix = merged_df.corr()
abs(corr_matrix['hic']).sort_values(ascending=False)
# Out:
# hic       1.000000
# vehlen    0.105932
# t2        0.101504
# whlbas    0.094760
# t1        0.092671
# tstno     0.077424
# time      0.074768
# vehwid    0.044345
# lencnt    0.031490
# vehcg     0.026001
# vehspd    0.014842
# engdsp    0.009401
# crbang    0.005048
# pdof      0.004009
# vehno     0.003300
# Name: hic, dtype: float64

# %%
len(df)
# Out:
# 10362

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df, target, shuffle= True, random_state=42, test_size=0.05)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, shuffle= True, random_state= 42, test_size=.055)

# %%
print(
f'Train size: {len(x_train), len(y_train)}\n'
f'Val size: {len(x_val), len(y_val)}\n'
f'Test size: {len(x_test), len(y_test)}'
)
# Out:
# Train size: (9301, 9301)
# Val size: (542, 542)
# Test size: (519, 519)

# %%
df[num_cols].isna().sum()
# Out:
# engdsp    491
# whlbas    421
# vehlen    386
# vehwid    642
# vehcg     510
# vehspd     66
# crbang    191
# pdof      136
# lencnt    817
# t1         21
# t2         34
# dtype: int64
